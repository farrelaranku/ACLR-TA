# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = r'checkpoints\weather_ACLR_96_96_iTransformer_custom_M_ft96_sl48_ll96_pl512_dm8_nh3_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w96 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\weather_ACLR_96_192_iTransformer_custom_M_ft96_sl48_ll192_pl512_dm8_nh3_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w192 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\weather_ACLR_96_336_iTransformer_custom_M_ft96_sl48_ll336_pl512_dm8_nh3_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w336 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\weather_ACLR_96_720_iTransformer_custom_M_ft96_sl48_ll720_pl512_dm8_nh3_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w720 = pd.read_csv(file_path, delimiter=',', header=None)

# %%
plt.figure(figsize=(10, 6))
plt.plot(w96.iloc[:, 2], label='96')
# plt.plot(w192.iloc[:].index + 1, w192.iloc[:, 2], label='192')
# plt.plot(w336.iloc[:].index + 1, w336.iloc[:, 2], label='336')
# plt.plot(w720.iloc[:].index + 1, w720.iloc[:, 2], label='720')
plt.xlabel('Iteration')
plt.ylabel('Learning Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
# plt.plot(w96.iloc[:].index + 1, w96.iloc[:, 2], label='96')
plt.plot(w96.iloc[:355, 2], label='96')
# plt.plot(w192.iloc[:].index + 1, w192.iloc[:, 2], label='192')
# plt.plot(w336.iloc[:].index + 1, w336.iloc[:, 2], label='336')
# plt.plot(w720.iloc[:].index + 1, w720.iloc[:, 2], label='720')
plt.xlabel('Iteration')
plt.ylabel('Learning Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
# plt.plot(w96.iloc[:].index + 1, w96.iloc[:, 2], label='96')
plt.plot(w96.iloc[:175, 2], label='96')
# plt.plot(w192.iloc[:].index + 1, w192.iloc[:, 2], label='192')
# plt.plot(w336.iloc[:].index + 1, w336.iloc[:, 2], label='336')
# plt.plot(w720.iloc[:].index + 1, w720.iloc[:, 2], label='720')
plt.xlabel('Iteration')
plt.ylabel('Learning Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
# plt.plot(w96.iloc[:].index + 1, w96.iloc[:, 2], label='96')
plt.plot(w96.iloc[:72, 2], label='96')
# plt.plot(w192.iloc[:].index + 1, w192.iloc[:, 2], label='192')
# plt.plot(w336.iloc[:].index + 1, w336.iloc[:, 2], label='336')
# plt.plot(w720.iloc[:].index + 1, w720.iloc[:, 2], label='720')
plt.xlabel('Iteration')
plt.ylabel('Learning Rate')
plt.legend()
plt.grid(True)
plt.show()
