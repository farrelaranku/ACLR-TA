# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#WEATHER

file_path = r'checkpoints\weather_ACLR_96_96_iTransformer_custom_M_ft96_sl48_ll96_pl512_dm8_nh3_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w96 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\weather_ACLR_96_192_iTransformer_custom_M_ft96_sl48_ll192_pl512_dm8_nh3_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w192 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\weather_ACLR_96_336_iTransformer_custom_M_ft96_sl48_ll336_pl512_dm8_nh3_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w336 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\weather_ACLR_96_720_iTransformer_custom_M_ft96_sl48_ll720_pl512_dm8_nh3_el1_dl512_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w720 = pd.read_csv(file_path, delimiter=',', header=None)

#EXCHANGE

file_path = r'checkpoints\Exchange_ACLR_96_96_iTransformer_custom_M_ft96_sl48_ll96_pl128_dm8_nh2_el1_dl128_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
ex96 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\Exchange_ACLR_96_192_iTransformer_custom_M_ft96_sl48_ll192_pl128_dm8_nh2_el1_dl128_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
ex192 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ExchangeHANDLENAN_ACLR_96_336_iTransformer_custom_M_ft96_sl48_ll336_pl128_dm8_nh2_el1_dl128_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
ex336 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ExchangeHANDLENAN_ACLR_96_720_iTransformer_exchange_high_M_ft96_sl48_ll720_pl128_dm8_nh2_el1_dl128_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
ex720 = pd.read_csv(file_path, delimiter=',', header=None)

#ETTm2

file_path = r'checkpoints\ETTm2_ACLR_96_96_iTransformer_custom_M_ft96_sl48_ll96_pl128_dm8_nh2_el1_dl128_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
et96 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ETTm2_ACLR_96_192_iTransformer_custom_M_ft96_sl48_ll192_pl128_dm8_nh2_el1_dl128_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
et192 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ETTm2_ACLR_96_336_iTransformer_custom_M_ft96_sl48_ll336_pl128_dm8_nh2_el1_dl128_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
et336 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ETTm2_ACLR_96_720_iTransformer_custom_M_ft96_sl48_ll720_pl128_dm8_nh2_el1_dl128_df1_fctimeF_ebTrue_dtExp_projection_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
et720 = pd.read_csv(file_path, delimiter=',', header=None)

# %%
data_dict = {
    '96': w96,
    '192': w192,
    '336': w336,
    '720': w720
}

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Learning Rate per Iteration', fontsize=14)

for i, (key, df) in enumerate(data_dict.items()):
    row, col = divmod(i, 2)
    ax = axs[row][col]
    half_len = len(df) // 2
    ax.plot(df.iloc[:half_len, 2], label=f'Pred Len {key}')
    ax.set_title(f'Prediction Length: {key}')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Learning Rate')
    ax.legend()
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Biar title utama ga ketimpa
plt.show()

# %%
data_dict = {
    '96': ex96,
    '192': ex192,
    '336': ex336,
    '720': ex720
}

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Learning Rate per Iteration', fontsize=14)

for i, (key, df) in enumerate(data_dict.items()):
    row, col = divmod(i, 2)
    ax = axs[row][col]
    half_len = len(df) // 2
    print(half_len)
    ax.plot(df.iloc[:half_len, 2], label=f'Pred Len {key}')
    ax.set_title(f'Prediction Length: {key}')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Learning Rate')
    ax.legend()
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Biar title utama ga ketimpa
plt.show()
# Out:
# 25
# 45
# 95
# 96

# %%
data_dict = {
    '96': et96,
    '192': et192,
    '336': et336,
    '720': et720
}

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Learning Rate per Iteration', fontsize=14)

for i, (key, df) in enumerate(data_dict.items()):
    row, col = divmod(i, 2)
    ax = axs[row][col]
    half_len = len(df) // 2
    ax.plot(df.iloc[:half_len, 2], label=f'Pred Len {key}')
    ax.set_title(f'Prediction Length: {key}')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Learning Rate')
    ax.legend()
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Biar title utama ga ketimpa
plt.show()
