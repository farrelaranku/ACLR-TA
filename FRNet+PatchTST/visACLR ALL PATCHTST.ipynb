# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#WEATHER

file_path = r'checkpoints\WeatherACLR_96_96_PatchTST_custom_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w96 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\WeatherACLR_96_192_PatchTST_custom_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w192 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\WeatherACLR_96_336_PatchTST_custom_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w336 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\WeatherACLR_96_720_PatchTST_custom_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
w720 = pd.read_csv(file_path, delimiter=',', header=None)

#EXCHANGE

file_path = r'checkpoints\ExchangeACLR_96_96_PatchTST_custom_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
ex96 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ExchangeACLR_96_192_PatchTST_custom_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
ex192 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ExchangeACLR_96_336_PatchTST_custom_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
ex336 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ExchangeACLR_96_720_PatchTST_exchange_high_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
ex720 = pd.read_csv(file_path, delimiter=',', header=None)

#ETTm2

file_path = r'checkpoints\ETTm2ACLR_96_96_PatchTST_ETTm2_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
et96 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ETTm2ACLR_96_192_PatchTST_ETTm2_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
et192 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ETTm2ACLR_96_336_PatchTST_ETTm2_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
et336 = pd.read_csv(file_path, delimiter=',', header=None)

file_path = r'checkpoints\ETTm2ACLR_96_720_PatchTST_ETTm2_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\train_results\iter.txt'
file_path = file_path.replace('\\', '/')
et720 = pd.read_csv(file_path, delimiter=',', header=None)

# %%
data_dict = {
    '96': w96,
    '192': w192,
    '336': w336,
    '720': w720
}

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Learning Rate per Iteration', fontsize=14)

for i, (key, df) in enumerate(data_dict.items()):
    row, col = divmod(i, 2)
    ax = axs[row][col]
    half_len = len(df) // 2
    ax.plot(df.iloc[:half_len, 2], label=f'Pred Len {key}')
    ax.set_title(f'Prediction Length: {key}')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Learning Rate')
    ax.legend()
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Biar title utama ga ketimpa
plt.show()

# %%
data_dict = {
    '96': ex96,
    '192': ex192,
    '336': ex336,
    '720': ex720
}

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Learning Rate per Iteration', fontsize=14)

for i, (key, df) in enumerate(data_dict.items()):
    row, col = divmod(i, 2)
    ax = axs[row][col]
    half_len = len(df) // 2
    print(half_len)
    ax.plot(df.iloc[:half_len, 2], label=f'Pred Len {key}')
    ax.set_title(f'Prediction Length: {key}')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Learning Rate')
    ax.legend()
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Biar title utama ga ketimpa
plt.show()
# Out:
# 35
# 40
# 57
# 80

# %%
data_dict = {
    '96': et96,
    '192': et192,
    '336': et336,
    '720': et720
}

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Learning Rate per Iteration', fontsize=14)

for i, (key, df) in enumerate(data_dict.items()):
    row, col = divmod(i, 2)
    ax = axs[row][col]
    half_len = len(df) // 2
    ax.plot(df.iloc[:half_len, 2], label=f'Pred Len {key}')
    ax.set_title(f'Prediction Length: {key}')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Learning Rate')
    ax.legend()
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Biar title utama ga ketimpa
plt.show()
