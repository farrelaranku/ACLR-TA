# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
gt_w96 = r'results\Weather_96_96_PatchTST_custom_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\true.npy'
gt_w96.replace('\\', '/')
pred_w96 = r'results\Weather_96_96_PatchTST_custom_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy'
pred_w96.replace('\\', '/')
pred_w96_aclr = r'results\WeatherACLR_96_96_PatchTST_custom_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy'
pred_w96_aclr.replace('\\', '/')

gt_w192 = r'results\Weather_96_192_PatchTST_custom_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\true.npy'
gt_w192.replace('\\', '/')
pred_w192 = r'results\Weather_96_192_PatchTST_custom_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy'
pred_w192.replace('\\', '/') 
pred_w192_aclr = r'results\WeatherACLR_96_192_PatchTST_custom_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy'
pred_w192_aclr.replace('\\', '/')

gt_w336 = r'results\Weather_96_336_PatchTST_custom_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\true.npy'
gt_w336.replace('\\', '/')
pred_w336 = r'results\Weather_96_336_PatchTST_custom_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy'
pred_w336.replace('\\', '/')
pred_w336_aclr = r'results\WeatherACLR_96_336_PatchTST_custom_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy'
pred_w336_aclr.replace('\\', '/')

gt_w720 = r'results\Weather_96_720_PatchTST_custom_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\true.npy'
gt_w720.replace('\\', '/')
pred_w720 = r'results\Weather_96_720_PatchTST_custom_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy'
pred_w720.replace('\\', '/')
pred_w720_aclr = r'results\WeatherACLR_96_720_PatchTST_custom_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy'
pred_w720_aclr.replace('\\', '/')
# Out:
# 'results/WeatherACLR_96_720_PatchTST_custom_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy'

# %%
gt96 = np.load(gt_w96)
pred96 = np.load(pred_w96)
pred_aclr96 = np.load(pred_w96_aclr)
gt192 = np.load(gt_w192)
pred192 = np.load(pred_w192)
pred_aclr192 = np.load(pred_w192_aclr)
gt336 = np.load(gt_w336)
pred336 = np.load(pred_w336)
pred_aclr336 = np.load(pred_w336_aclr)
gt720 = np.load(gt_w720)
pred720 = np.load(pred_w720)
pred_aclr720 = np.load(pred_w720_aclr)

# %%
print(gt96.shape)
print(gt192.shape)
print(gt336.shape)
print(gt720.shape)
# Out:
# (10240, 96, 21)
# (10240, 192, 21)
# (9728, 336, 21)
# (9728, 720, 21)

# %%
# List semua data prediksi dan ground truth sesuai pred_len
pred_lens = [96, 192, 336, 720]
gt_list = [gt96, gt192, gt336, gt720]
pred_list = [pred96, pred192, pred336, pred720]
pred_aclr_list = [pred_aclr96, pred_aclr192, pred_aclr336, pred_aclr720]

# Pilih indeks sampel yang ingin divisualisasikan
i = 124
# i = random.randrange(1, 1000)
# i = 500
print(i)

# Buat figure dan axis 2x2
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

# Loop visualisasi untuk tiap prediction length
for idx, step in enumerate(pred_lens):
    gt = gt_list[idx]
    pred = pred_list[idx]
    pred_aclr = pred_aclr_list[idx]

    true = gt[i, :, -1]
    predict = pred[i, :, -1]
    predict_aclr = pred_aclr[i, :, -1]

    ax = axs[idx]
    ax.set_title(f'Prediction Length = {step}')
    ax.plot(true, label='GroundTruth', linewidth=3)
    ax.plot(predict_aclr, label='With ACLR', linewidth=2.5)
    ax.plot(predict, label='No ACLR', linewidth=1)
    ax.set_xlabel('Time step')
    ax.set_ylabel('Value')
    ax.grid(True)
    ax.legend()

# Rapikan layout
plt.tight_layout()
plt.suptitle('Perbandingan Prediksi Pada Dataset Weather', fontsize=16, y=1.02)
plt.show()
# Out:
# 124

# %%
gt_ex96 = np.load(r'results\Exchange_96_96_PatchTST_custom_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\true.npy')
pred_ex96 = np.load(r'results\Exchange_96_96_PatchTST_custom_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\pred.npy')
pred_ex_aclr96 = np.load(r'results\ExchangeACLR_96_96_PatchTST_custom_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\pred.npy')

gt_ex192 = np.load(r'results\Exchange_96_192_PatchTST_custom_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\true.npy')
pred_ex192 = np.load(r'results\Exchange_96_192_PatchTST_custom_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\pred.npy')
pred_ex_aclr192 = np.load(r'results\ExchangeACLR_96_192_PatchTST_custom_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\pred.npy')

gt_ex336 = np.load(r'results\Exchange_96_336_PatchTST_custom_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\true.npy')
pred_ex336 = np.load(r'results\Exchange_96_336_PatchTST_custom_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\pred.npy')
pred_ex_aclr336 = np.load(r'results\ExchangeACLR_96_336_PatchTST_custom_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\pred.npy')

gt_ex720 = np.load(r'results\Exchange_96_720_PatchTST_exchange_high_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\true.npy')
pred_ex720 = np.load(r'results\Exchange_96_720_PatchTST_exchange_high_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\pred.npy')
pred_ex_aclr720 = np.load(r'results\ExchangeACLR_96_720_PatchTST_exchange_high_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc3_ebtimeF_dtTrue_Exp_0\pred.npy')

# %%
print(gt_ex96.shape)
print(gt_ex192.shape)
print(gt_ex336.shape)
print(gt_ex720.shape)
# Out:
# (1024, 96, 8)
# (1024, 192, 8)
# (1024, 336, 8)
# (768, 720, 8)

# %%
# List semua data prediksi dan ground truth sesuai pred_len
pred_lens = [96, 192, 336, 720]
gt_list = [gt_ex96, gt_ex192, gt_ex336, gt_ex720]
pred_list = [pred_ex96, pred_ex192, pred_ex336, pred_ex720]
pred_aclr_list = [pred_ex_aclr96, pred_ex_aclr192, pred_ex_aclr336, pred_ex_aclr720]

# Pilih indeks sampel yang ingin divisualisasikan
i = 141
# i = random.randrange(1, 700)
# i = 59
print(i)

# Buat figure dan axis 2x2
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

# Loop visualisasi untuk tiap prediction length
for idx, step in enumerate(pred_lens):
    gt = gt_list[idx]
    pred = pred_list[idx]
    pred_aclr = pred_aclr_list[idx]

    true = gt[i, :, -1]
    predict = pred[i, :, -1]
    predict_aclr = pred_aclr[i, :, -1]

    ax = axs[idx]
    ax.set_title(f'Prediction Length = {step}')
    ax.plot(true, label='GroundTruth', linewidth=3)
    ax.plot(predict_aclr, label='With ACLR', linewidth=2.5)
    ax.plot(predict, label='No ACLR', linewidth=1)
    ax.set_xlabel('Time step')
    ax.set_ylabel('Value')
    ax.grid(True)
    ax.legend()

# Rapikan layout
plt.tight_layout()
plt.suptitle('Perbandingan Prediksi Pada Dataset Exchange Rate', fontsize=16, y=1.02)
plt.show()
# Out:
# 141

# %%
gt_et96 = np.load(r'results\ETTm2_96_96_PatchTST_ETTm2_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\true.npy')
pred_et96 = np.load(r'results\ETTm2_96_96_PatchTST_ETTm2_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy')
pred_et_aclr96 = np.load(r'results\ETTm2ACLR_96_96_PatchTST_ETTm2_ftM_sl96_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy')

gt_et192 = np.load(r'results\ETTm2_96_192_PatchTST_ETTm2_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\true.npy')
pred_et192 = np.load(r'results\ETTm2_96_192_PatchTST_ETTm2_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy')
pred_et_aclr192 = np.load(r'results\ETTm2ACLR_96_192_PatchTST_ETTm2_ftM_sl96_ll48_pl192_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy')

gt_et336 = np.load(r'results\ETTm2_96_336_PatchTST_ETTm2_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\true.npy')
pred_et336 = np.load(r'results\ETTm2_96_336_PatchTST_ETTm2_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy')
pred_et_aclr336 = np.load(r'results\ETTm2ACLR_96_336_PatchTST_ETTm2_ftM_sl96_ll48_pl336_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy')

gt_et720 = np.load(r'results\ETTm2_96_720_PatchTST_ETTm2_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\true.npy')
pred_et720 = np.load(r'results\ETTm2_96_720_PatchTST_ETTm2_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy')
pred_et_aclr720 = np.load(r'results\ETTm2ACLR_96_720_PatchTST_ETTm2_ftM_sl96_ll48_pl720_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0\pred.npy')

# %%
print(gt_et96.shape)
print(gt_et192.shape)
print(gt_et336.shape)
print(gt_et720.shape)
# Out:
# (11264, 96, 7)
# (11264, 192, 7)
# (10752, 336, 7)
# (10752, 720, 7)

# %%
# List semua data prediksi dan ground truth sesuai pred_len
pred_lens = [96, 192, 336, 720]
gt_list = [gt_et96, gt_et192, gt_et336, gt_et720]
pred_list = [pred_et96, pred_et192, pred_et336, pred_et720]
pred_aclr_list = [pred_et_aclr96, pred_et_aclr192, pred_et_aclr336, pred_et_aclr720]

# Pilih indeks sampel yang ingin divisualisasikan

# i = random.randrange(1, 10500)
i = 3080

print(i)

# Buat figure dan axis 2x2
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

# Loop visualisasi untuk tiap prediction length
for idx, step in enumerate(pred_lens):
    gt = gt_list[idx]
    pred = pred_list[idx]
    pred_aclr = pred_aclr_list[idx]

    true = gt[i, :, -1]
    predict = pred[i, :, -1]
    predict_aclr = pred_aclr[i, :, -1]

    ax = axs[idx]
    ax.set_title(f'Prediction Length = {step}')
    ax.plot(true, label='GroundTruth', linewidth=3)
    ax.plot(predict_aclr, label='With ACLR', linewidth=2.5)
    ax.plot(predict, label='No ACLR', linewidth=1)
    ax.set_xlabel('Time step')
    ax.set_ylabel('Value')
    ax.grid(True)
    ax.legend()

# Rapikan layout
plt.tight_layout()
plt.suptitle('Perbandingan Prediksi Pada Dataset ETTm2', fontsize=16, y=1.02)
plt.show()
# Out:
# 3080

# %%
# Plot the ground truth data for gt720
plt.figure(figsize=(10, 6))
plt.plot(gt720[74, :, -1], linewidth=2)
# plt.title('Ground Truth for Prediction Length = 720')
plt.xlabel('Time step')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\NCC Laboratory\AppData\Local\Temp\ipykernel_16024\755075774.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot the ground truth data for gt720
plt.figure(figsize=(10, 6))
plt.plot(gt_ex720[74, :, -1], linewidth=2)
# plt.title('Ground Truth for Prediction Length = 720')
plt.xlabel('Time step')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\NCC Laboratory\AppData\Local\Temp\ipykernel_16024\394713128.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot the ground truth data for gt720
plt.figure(figsize=(10, 6))
plt.plot(gt_et720[12488, :, -1], linewidth=2)
# plt.title('Ground Truth for Prediction Length = 720')
plt.xlabel('Time step')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Plot the ground truth data for gt720
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.plot(gt_et720[12488, :, -1], linewidth=2)
#       4 # plt.title('Ground Truth for Prediction Length = 720')
#       5 plt.xlabel('Time step')
#
# IndexError: index 12488 is out of bounds for axis 0 with size 10752
